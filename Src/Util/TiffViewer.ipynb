# %%
from Constant import *
from Util.TiffUtil import show_tiff

# %%
file_path = os.path.join(INFERENCE_DIR_PATH, RESOLUTION_1KM, "20170117.tif")
show_tiff(file_path)
# Out:
# Transform:  | 1000.00, 0.00,-11579000.00|
# | 0.00,-1000.00, 5531000.00|
# | 0.00, 0.00, 1.00|
# Bounds:  (-120.00669908603314, 34.98405486847652, -103.98369564989814, 49.00529064494787)
# Resolution (pixel size):  (1000.0, 1000.0)
# Data shape:  (1334, 1546)

# %%
from Util.TiffUtil import show_tiff

file_path = os.path.join("../../Data/20160101.tif")
show_tiff(file_path)
# Out:
# Transform:  | 1000.00, 0.00,-11579000.00|
# | 0.00,-1000.00, 5531000.00|
# | 0.00, 0.00, 1.00|
# Bounds:  (-120.00669908603314, 34.98405486847652, -103.98369564989814, 49.00529064494787)
# Resolution (pixel size):  (1000.0, 1000.0)
# Data shape:  (1334, 1546)
